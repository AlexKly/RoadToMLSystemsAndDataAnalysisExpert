# %% [markdown]
# **Корректность проверена на Python 3.6:**
# + numpy 1.15.4
# + matplotlib 3.0.2
# + pandas 0.23.4

# %% [markdown]
# # Практическое задание к уроку 1 (2 неделя).
# ## Линейная регрессия: переобучение и регуляризация

# %% [markdown]
# В этом задании мы на примерах увидим, как переобучаются линейные модели, разберем, почему так происходит, и выясним, как диагностировать и контролировать переобучение.
#
# Во всех ячейках, где написан комментарий с инструкциями, нужно написать код, выполняющий эти инструкции. Остальные ячейки с кодом (без комментариев) нужно просто выполнить. Кроме того, в задании требуется отвечать на вопросы; ответы нужно вписывать после выделенного слова "__Ответ:__".
#
# Напоминаем, что посмотреть справку любого метода или функции (узнать, какие у нее аргументы и что она делает) можно с помощью комбинации Shift+Tab. Нажатие Tab после имени объекта и точки позволяет посмотреть, какие методы и переменные есть у этого объекта.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# Мы будем работать с датасетом __"bikes_rent.csv"__, в котором по дням записаны календарная информация и погодные условия, характеризующие автоматизированные пункты проката велосипедов, а также число прокатов в этот день. Последнее мы будем предсказывать; таким образом, мы будем решать задачу регрессии.

# %% [markdown]
# ### Знакомство с данными

# %% [markdown]
# Загрузите датасет с помощью функции __pandas.read_csv__ в переменную __df__. Выведите первые 5 строчек, чтобы убедиться в корректном считывании данных:

# %%
# (0 баллов)
# Считайте данные и выведите первые 5 строк
df = pd.read_csv('bikes_rent.csv')
df.head()
# Out:
#    season  yr  mnth  holiday  weekday  workingday  weathersit       temp  \
# 0       1   0     1        0        6           0           2  14.110847
# 1       1   0     1        0        0           0           2  14.902598
# 2       1   0     1        0        1           1           1   8.050924
# 3       1   0     1        0        2           1           1   8.200000
# 4       1   0     1        0        3           1           1   9.305237
#
#       atemp      hum  windspeed(mph)  windspeed(ms)   cnt
# 0  18.18125  80.5833       10.749882       4.805490   985
# 1  17.68695  69.6087       16.652113       7.443949   801
# 2   9.47025  43.7273       16.636703       7.437060  1349
# 3  10.60610  59.0435       10.739832       4.800998  1562
# 4  11.46350  43.6957       12.522300       5.597810  1600

# %% [markdown]
# Для каждого дня проката известны следующие признаки (как они были указаны в источнике данных):
# * _season_: 1 - весна, 2 - лето, 3 - осень, 4 - зима
# * _yr_: 0 - 2011, 1 - 2012
# * _mnth_: от 1 до 12
# * _holiday_: 0 - нет праздника, 1 - есть праздник
# * _weekday_: от 0 до 6
# * _workingday_: 0 - нерабочий день, 1 - рабочий день
# * _weathersit_: оценка благоприятности погоды от 1 (чистый, ясный день) до 4 (ливень, туман)
# * _temp_: температура в Цельсиях
# * _atemp_: температура по ощущениям в Цельсиях
# * _hum_: влажность
# * _windspeed(mph)_: скорость ветра в милях в час
# * _windspeed(ms)_: скорость ветра в метрах в секунду
# * _cnt_: количество арендованных велосипедов (это целевой признак, его мы будем предсказывать)
#
# Итак, у нас есть вещественные, бинарные и номинальные (порядковые) признаки, и со всеми из них можно работать как с вещественными. С номинальныеми признаками тоже можно работать как с вещественными, потому что на них задан порядок. Давайте посмотрим на графиках, как целевой признак зависит от остальных

# %%
fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(15, 10))
for idx, feature in enumerate(df.columns[:-1]):
    df.plot(feature, "cnt", subplots=True, kind="scatter", ax=axes[idx // 4, idx % 4])

# %% [markdown]
# __Блок 1. Ответьте на вопросы (каждый 0.5 балла):__
# 1. Каков характер зависимости числа прокатов от месяца?
#    * ответ: зависимость числа прокатов от месяца схожа с нормальным законом.
# 1. Укажите один или два признака, от которых число прокатов скорее всего зависит линейно
#    * ответ: yr, temp, atemp.

# %% [markdown]
# Давайте более строго оценим уровень линейной зависимости между признаками и целевой переменной. Хорошей мерой линейной зависимости между двумя векторами является корреляция Пирсона. В pandas ее можно посчитать с помощью двух методов датафрейма: corr и corrwith. Метод df.corr вычисляет матрицу корреляций всех признаков из датафрейма. Методу df.corrwith нужно подать еще один датафрейм в качестве аргумента, и тогда он посчитает попарные корреляции между признаками из df и этого датафрейма.

# %%
# Код 1.1 (0.5 балла)
# Посчитайте корреляции всех признаков, кроме последнего, с последним с помощью метода corrwith:
df[df.columns[:-1]].corrwith(df['cnt'])
# Out:
# season            0.406100
# yr                0.566710
# mnth              0.279977
# holiday          -0.068348
# weekday           0.067443
# workingday        0.061156
# weathersit       -0.297391
# temp              0.627494
# atemp             0.631066
# hum              -0.100659
# windspeed(mph)   -0.234545
# windspeed(ms)    -0.234545
# dtype: float64

# %% [markdown]
# В выборке есть признаки, коррелирующие с целевым, а значит, задачу можно решать линейными методами.

# %% [markdown]
# По графикам видно, что некоторые признаки похожи друг на друга. Поэтому давайте также посчитаем корреляции между вещественными признаками.

# %%
# Код 1.2 (0.5 балла)
# Посчитайте попарные корреляции между признаками temp, atemp, hum, windspeed(mph), windspeed(ms) и cnt
# с помощью метода corr:
features_columns = ['temp', 'atemp', 'hum', 'windspeed(mph)', 'windspeed(ms)', 'cnt']
df[features_columns].corr()
# Out:
#                     temp     atemp       hum  windspeed(mph)  windspeed(ms)  \
# temp            1.000000  0.991702  0.126963       -0.157944      -0.157944
# atemp           0.991702  1.000000  0.139988       -0.183643      -0.183643
# hum             0.126963  0.139988  1.000000       -0.248489      -0.248489
# windspeed(mph) -0.157944 -0.183643 -0.248489        1.000000       1.000000
# windspeed(ms)  -0.157944 -0.183643 -0.248489        1.000000       1.000000
# cnt             0.627494  0.631066 -0.100659       -0.234545      -0.234545
#
#                      cnt
# temp            0.627494
# atemp           0.631066
# hum            -0.100659
# windspeed(mph) -0.234545
# windspeed(ms)  -0.234545
# cnt             1.000000

# %% [markdown]
# На диагоналях, как и полагается, стоят единицы. Однако в матрице имеются еще две пары сильно коррелирующих столбцов: temp и atemp (коррелируют по своей природе) и два windspeed (потому что это просто перевод одних единиц в другие). Далее мы увидим, что этот факт негативно сказывается на обучении линейной модели.

# %% [markdown]
# Напоследок посмотрим средние признаков (метод mean), чтобы оценить масштаб признаков и доли 1 у бинарных признаков.

# %%
# Код 1.3 (0.5 балла)
# Выведите средние признаков
np.mean(df, axis=0)
# Out:
# season               2.496580
# yr                   0.500684
# mnth                 6.519836
# holiday              0.028728
# weekday              2.997264
# workingday           0.683995
# weathersit           1.395349
# temp                20.310776
# atemp               23.717699
# hum                 62.789406
# windspeed(mph)      12.762576
# windspeed(ms)        5.705220
# cnt               4504.348837
# dtype: float64

# %% [markdown]
# Признаки имеют разный масштаб, значит для дальнейшей работы нам лучше нормировать матрицу объекты-признаки.

# %% [markdown]
# ### Проблема первая: коллинеарные признаки

# %% [markdown]
# Итак, в наших данных один признак дублирует другой, и есть еще два очень похожих. Конечно, мы могли бы сразу удалить дубликаты, но давайте посмотрим, как бы происходило обучение модели, если бы мы не заметили эту проблему.
#
# Для начала проведем масштабирование, или стандартизацию признаков: из каждого признака вычтем его среднее и поделим на стандартное отклонение. Это можно сделать с помощью метода scale.
#
# Кроме того, нужно перемешать выборку, это потребуется для кросс-валидации.

# %%
from sklearn.preprocessing import scale
from sklearn.utils import shuffle

# %%
df_shuffled = shuffle(df, random_state=123)
X = scale(df_shuffled[df_shuffled.columns[:-1]])
y = df_shuffled["cnt"]

# %% [markdown]
# Давайте обучим линейную регрессию на наших данных и посмотрим на веса признаков.

# %%
from sklearn.linear_model import LinearRegression

# %%
# Код 2.1 (1 балл)
# Создайте объект линейного регрессора, обучите его на всех данных и выведите веса модели 
# (веса хранятся в переменной coef_ класса регрессора).
# Можно выводить пары (название признака, вес), воспользовавшись функцией zip, встроенной в язык python
# Названия признаков хранятся в переменной df.columns
linear_regressor = LinearRegression()
linear_regressor.fit(X, y)
for name_feature, coef in zip(df.columns, linear_regressor.coef_):
    print(name_feature, coef)
# Out:
# season 570.8719592302759
# yr 1021.9635898212942
# mnth -141.30585587144665
# holiday -86.75647149074891
# weekday 137.2260362759306
# workingday 56.390724502512256
# weathersit -330.2291534403052
# temp 367.46916495965974
# atemp 585.5606071882255
# hum -145.6111431908375
# windspeed(mph) 12457587117893.193
# windspeed(ms) -12457587118091.646

# %% [markdown]
# Мы видим, что веса при линейно-зависимых признаках по модулю значительно больше, чем при других признаках.

# %% [markdown]
# Чтобы понять, почему так произошло, вспомним аналитическую формулу, по которой вычисляются веса линейной модели в методе наименьших квадратов:
#
# $w = (X^TX)^{-1} X^T y$.
#
# Если в X есть коллинеарные (линейно-зависимые) столбцы, матрица $X^TX$ становится вырожденной, и формула перестает быть корректной. Чем более зависимы признаки, тем меньше определитель этой матрицы и тем хуже аппроксимация $Xw \approx y$. Такая ситуацию называют _проблемой мультиколлинеарности_, вы обсуждали ее на лекции.

# %% [markdown]
# С парой temp-atemp чуть менее коррелирующих переменных такого не произошло, однако на практике всегда стоит внимательно следить за коэффициентами при похожих признаках.

# %% [markdown]
# __Решение__ проблемы мультиколлинеарности состоит в _регуляризации_ линейной модели. К оптимизируемому функционалу прибавляют L1 или L2 норму весов, умноженную на коэффициент регуляризации $\alpha$. В первом случае метод называется Lasso, а во втором --- Ridge. Подробнее об этом также рассказано в лекции.

# %% [markdown]
# Обучите регрессоры Ridge и Lasso с параметрами по умолчанию и убедитесь, что проблема с весами решилась.

# %%
from sklearn.linear_model import Lasso, Ridge

# %%
# Код 2.2 (0.5 балла)
# Обучите линейную модель с L1-регуляризацией и выведите веса
lasso_regressor = Lasso()
lasso_regressor.fit(X, y)
for name_feature, coef in zip(df.columns, lasso_regressor.coef_):
    print(name_feature, coef)
# Out:
# season 560.2416160308867
# yr 1019.4634940657196
# mnth -128.73062703678738
# holiday -86.15278133371112
# weekday 137.3478939049632
# workingday 55.21237064135662
# weathersit -332.3698569623486
# temp 376.36323620969586
# atemp 576.5307935045539
# hum -144.12915500348598
# windspeed(mph) -197.13968940249575
# windspeed(ms) -2.8039823678320867e-08

# %%
# Код 2.3 (0.5 балла)
# Обучите линейную модель с L2-регуляризацией и выведите веса
ridge_regressor = Ridge()
ridge_regressor.fit(X, y)
for name_feature, coef in zip(df.columns, ridge_regressor.coef_):
    print(name_feature, coef)
# Out:
# season 563.0645722520152
# yr 1018.9483787875273
# mnth -131.87332028247525
# holiday -86.74609799709252
# weekday 138.00511117871923
# workingday 55.903110375064365
# weathersit -332.34978849907293
# temp 386.4578891919104
# atemp 566.3470470600653
# hum -145.07132729867268
# windspeed(mph) -99.25944108185134
# windspeed(ms) -99.25944115428139

# %% [markdown]
# ### Проблема вторая: неинформативные признаки

# %% [markdown]
# В отличие от L2-регуляризации, L1 обнуляет веса при некоторых признаках. Объяснение данному факту дается в одной из лекций курса.
#
# Давайте пронаблюдаем, как меняются веса при увеличении коэффициента регуляризации $\alpha$ (в лекции коэффициент при регуляризаторе мог быть обозначен другой буквой).

# %%
# Код 3.1 (1 балл)
alphas = np.arange(1, 500, 50)
coefs_lasso = np.zeros((alphas.shape[0], X.shape[1])) # матрица весов размера (число регрессоров) x (число признаков)
coefs_ridge = np.zeros((alphas.shape[0], X.shape[1]))
# Для каждого значения коэффициента из alphas обучите регрессор Lasso
# и запишите веса в соответствующую строку матрицы coefs_lasso (вспомните встроенную в python функцию enumerate),
# а затем обучите Ridge и запишите веса в coefs_ridge.
for i in range(alphas.shape[0]):
    lasso = Lasso(alpha=alphas[i]).fit(X, y)
    ridge = Ridge(alpha=alphas[i]).fit(X, y)
    coefs_lasso[i] = lasso.coef_
    coefs_ridge[i] = ridge.coef_

# %% [markdown]
# Визуализируем динамику весов при увеличении параметра регуляризации:

# %%
plt.figure(figsize=(8, 5))
for coef, feature in zip(coefs_lasso.T, df.columns):
    plt.plot(alphas, coef, label=feature, color=np.random.rand(3))
plt.legend(loc="upper right", bbox_to_anchor=(1.4, 0.95))
plt.xlabel("alpha")
plt.ylabel("feature weight")
plt.title("Lasso")

plt.figure(figsize=(8, 5))
for coef, feature in zip(coefs_ridge.T, df.columns):
    plt.plot(alphas, coef, label=feature, color=np.random.rand(3))
plt.legend(loc="upper right", bbox_to_anchor=(1.4, 0.95))
plt.xlabel("alpha")
plt.ylabel("feature weight")
plt.title("Ridge")
# Out:
# Text(0.5, 1.0, 'Ridge')

# %% [markdown]
# Ответы на следующие вопросы можно давать, глядя на графики или выводя коэффициенты на печать.
#
# __Блок 2. Ответьте на вопросы (каждый 0.25 балла)__:
# 1. Какой регуляризатор (Ridge или Lasso) агрессивнее уменьшает веса при одном и том же alpha?
#     * Ответ: Lasso.
# 1. Что произойдет с весами Lasso, если alpha сделать очень большим? Поясните, почему так происходит.
#     * Ответ: зануляются, т.к. при увеличении коэффициента регуляризации сложность модели уменьшается.
# 1. Можно ли утверждать, что Lasso исключает один из признаков windspeed при любом значении alpha > 0? А Ridge? Ситается, что регуляризатор исключает признак, если коэффициент при нем < 1e-3.
#     * Ответ: Lasso исключается один из признаков windspeed сразу же в отличие от Ridge. Можем считать, что регуляризатор исключает признаки (в случае с Lasso), если при нем малой коэффициент.
# 1. Какой из регуляризаторов подойдет для отбора неинформативных признаков?
#     * Ответ: Lasso

# %% [markdown]
# Далее будем работать с Lasso.
#
# Итак, мы видим, что при изменении alpha модель по-разному подбирает коэффициенты признаков. Нам нужно выбрать наилучшее alpha.

# %% [markdown]
# Для этого, во-первых, нам нужна метрика качества. Будем использовать в качестве метрики сам оптимизируемый функционал метода наименьших квадратов, то есть Mean Square Error.
#
# Во-вторых, нужно понять, на каких данных эту метрику считать. Нельзя выбирать alpha по значению MSE на обучающей выборке, потому что тогда мы не сможем оценить, как модель будет делать предсказания на новых для нее данных. Если мы выберем одно разбиение выборки на обучающую и тестовую (это называется holdout), то настроимся на конкретные "новые" данные, и вновь можем переобучиться. Поэтому будем делать несколько разбиений выборки, на каждом пробовать разные значения alpha, а затем усреднять MSE. Удобнее всего делать такие разбиения кросс-валидацией, то есть разделить выборку на K частей, или блоков, и каждый раз брать одну из них как тестовую, а из оставшихся блоков составлять обучающую выборку.

# %% [markdown]
# Делать кросс-валидацию для регрессии в sklearn совсем просто: для этого есть специальный регрессор, __LassoCV__, который берет на вход список из alpha и для каждого из них вычисляет MSE на кросс-валидации. После обучения (установить параметр cv=3) регрессор будет содержать переменную __mse\_path\___, матрицу размера len(alpha) x k, k = 3 (число блоков в кросс-валидации), содержащую значения MSE на тесте для соответствующих запусков. Кроме того, в переменной alpha\_ будет храниться выбранное значение параметра регуляризации, а в coef\_, традиционно, обученные веса, соответствующие этому alpha_.
#
# Обратите внимание, что регрессор может менять порядок, в котором он проходит по alphas; для сопоставления с матрицей MSE лучше использовать переменную регрессора alphas_.

# %%
from sklearn.linear_model import LassoCV

# %%
# Код 3.2 (1 балл)
# Обучите регрессор LassoCV на всех параметрах регуляризации из alpha
# Постройте график _усредненного_ по строкам MSE в зависимости от alpha. 
# Выведите выбранное alpha, а также пары "признак-коэффициент" для обученного вектора коэффициентов
alphas = np.arange(1, 100, 5)
k = 3
lasso_cv = LassoCV(n_alphas=alphas.shape[0], alphas=alphas, cv=k).fit(X, y)
plt.plot(lasso_cv.alphas, np.mean(lasso_cv.mse_path_, axis=1))
for i in range(alphas.shape[0]):
    for j in range(lasso_cv.coef_.shape[0]):
        print('Alpha:', alphas[i], 'Feature:', df.columns[j], 'Coefficient:', lasso_cv.coef_[j])
# Out:
# Alpha: 1 Feature: season Coefficient: 532.0189828413535
# Alpha: 1 Feature: yr Coefficient: 1015.0602226430597
# Alpha: 1 Feature: mnth Coefficient: -100.03952614356626
# Alpha: 1 Feature: holiday Coefficient: -83.2939598752991
# Alpha: 1 Feature: weekday Coefficient: 132.50446549095798
# Alpha: 1 Feature: workingday Coefficient: 51.557085614073884
# Alpha: 1 Feature: weathersit Coefficient: -330.55985673998146
# Alpha: 1 Feature: temp Coefficient: 370.6798550300324
# Alpha: 1 Feature: atemp Coefficient: 581.3969310654994
# Alpha: 1 Feature: hum Coefficient: -140.00740550068855
# Alpha: 1 Feature: windspeed(mph) Coefficient: -191.7714084713612
# Alpha: 1 Feature: windspeed(ms) Coefficient: -2.6843848098919856e-08
# Alpha: 6 Feature: season Coefficient: 532.0189828413535
# Alpha: 6 Feature: yr Coefficient: 1015.0602226430597
# Alpha: 6 Feature: mnth Coefficient: -100.03952614356626
# Alpha: 6 Feature: holiday Coefficient: -83.2939598752991
# Alpha: 6 Feature: weekday Coefficient: 132.50446549095798
# Alpha: 6 Feature: workingday Coefficient: 51.557085614073884
# Alpha: 6 Feature: weathersit Coefficient: -330.55985673998146
# Alpha: 6 Feature: temp Coefficient: 370.6798550300324
# Alpha: 6 Feature: atemp Coefficient: 581.3969310654994
# Alpha: 6 Feature: hum Coefficient: -140.00740550068855
# Alpha: 6 Feature: windspeed(mph) Coefficient: -191.7714084713612
# Alpha: 6 Feature: windspeed(ms) Coefficient: -2.6843848098919856e-08
# Alpha: 11 Feature: season Coefficient: 532.0189828413535
# Alpha: 11 Feature: yr Coefficient: 1015.0602226430597
# Alpha: 11 Feature: mnth Coefficient: -100.03952614356626
# Alpha: 11 Feature: holiday Coefficient: -83.2939598752991
# Alpha: 11 Feature: weekday Coefficient: 132.50446549095798
# Alpha: 11 Feature: workingday Coefficient: 51.557085614073884
# Alpha: 11 Feature: weathersit Coefficient: -330.55985673998146
# Alpha: 11 Feature: temp Coefficient: 370.6798550300324
# Alpha: 11 Feature: atemp Coefficient: 581.3969310654994
# Alpha: 11 Feature: hum Coefficient: -140.00740550068855
# Alpha: 11 Feature: windspeed(mph) Coefficient: -191.7714084713612
# Alpha: 11 Feature: windspeed(ms) Coefficient: -2.6843848098919856e-08
# Alpha: 16 Feature: season Coefficient: 532.0189828413535
# Alpha: 16 Feature: yr Coefficient: 1015.0602226430597
# Alpha: 16 Feature: mnth Coefficient: -100.03952614356626
# Alpha: 16 Feature: holiday Coefficient: -83.2939598752991
# Alpha: 16 Feature: weekday Coefficient: 132.50446549095798
# Alpha: 16 Feature: workingday Coefficient: 51.557085614073884
# Alpha: 16 Feature: weathersit Coefficient: -330.55985673998146
# Alpha: 16 Feature: temp Coefficient: 370.6798550300324
# Alpha: 16 Feature: atemp Coefficient: 581.3969310654994
# Alpha: 16 Feature: hum Coefficient: -140.00740550068855
# Alpha: 16 Feature: windspeed(mph) Coefficient: -191.7714084713612
# Alpha: 16 Feature: windspeed(ms) Coefficient: -2.6843848098919856e-08
# Alpha: 21 Feature: season Coefficient: 532.0189828413535
# Alpha: 21 Feature: yr Coefficient: 1015.0602226430597
# Alpha: 21 Feature: mnth Coefficient: -100.03952614356626
# Alpha: 21 Feature: holiday Coefficient: -83.2939598752991
# Alpha: 21 Feature: weekday Coefficient: 132.50446549095798
# Alpha: 21 Feature: workingday Coefficient: 51.557085614073884
# Alpha: 21 Feature: weathersit Coefficient: -330.55985673998146
# Alpha: 21 Feature: temp Coefficient: 370.6798550300324
# Alpha: 21 Feature: atemp Coefficient: 581.3969310654994
# Alpha: 21 Feature: hum Coefficient: -140.00740550068855
# Alpha: 21 Feature: windspeed(mph) Coefficient: -191.7714084713612
# Alpha: 21 Feature: windspeed(ms) Coefficient: -2.6843848098919856e-08
# Alpha: 26 Feature: season Coefficient: 532.0189828413535
# Alpha: 26 Feature: yr Coefficient: 1015.0602226430597
# Alpha: 26 Feature: mnth Coefficient: -100.03952614356626
# Alpha: 26 Feature: holiday Coefficient: -83.2939598752991
# Alpha: 26 Feature: weekday Coefficient: 132.50446549095798
# Alpha: 26 Feature: workingday Coefficient: 51.557085614073884
# Alpha: 26 Feature: weathersit Coefficient: -330.55985673998146
# Alpha: 26 Feature: temp Coefficient: 370.6798550300324
# Alpha: 26 Feature: atemp Coefficient: 581.3969310654994
# Alpha: 26 Feature: hum Coefficient: -140.00740550068855
# Alpha: 26 Feature: windspeed(mph) Coefficient: -191.7714084713612
# Alpha: 26 Feature: windspeed(ms) Coefficient: -2.6843848098919856e-08
# Alpha: 31 Feature: season Coefficient: 532.0189828413535
# Alpha: 31 Feature: yr Coefficient: 1015.0602226430597
# Alpha: 31 Feature: mnth Coefficient: -100.03952614356626
# Alpha: 31 Feature: holiday Coefficient: -83.2939598752991
# Alpha: 31 Feature: weekday Coefficient: 132.50446549095798
# Alpha: 31 Feature: workingday Coefficient: 51.557085614073884
# Alpha: 31 Feature: weathersit Coefficient: -330.55985673998146
# Alpha: 31 Feature: temp Coefficient: 370.6798550300324
# Alpha: 31 Feature: atemp Coefficient: 581.3969310654994
# Alpha: 31 Feature: hum Coefficient: -140.00740550068855
# Alpha: 31 Feature: windspeed(mph) Coefficient: -191.7714084713612
# Alpha: 31 Feature: windspeed(ms) Coefficient: -2.6843848098919856e-08
# Alpha: 36 Feature: season Coefficient: 532.0189828413535
# Alpha: 36 Feature: yr Coefficient: 1015.0602226430597
# Alpha: 36 Feature: mnth Coefficient: -100.03952614356626
# Alpha: 36 Feature: holiday Coefficient: -83.2939598752991
# Alpha: 36 Feature: weekday Coefficient: 132.50446549095798
# Alpha: 36 Feature: workingday Coefficient: 51.557085614073884
# Alpha: 36 Feature: weathersit Coefficient: -330.55985673998146
# Alpha: 36 Feature: temp Coefficient: 370.6798550300324
# Alpha: 36 Feature: atemp Coefficient: 581.3969310654994
# Alpha: 36 Feature: hum Coefficient: -140.00740550068855
# Alpha: 36 Feature: windspeed(mph) Coefficient: -191.7714084713612
# Alpha: 36 Feature: windspeed(ms) Coefficient: -2.6843848098919856e-08
# Alpha: 41 Feature: season Coefficient: 532.0189828413535
# Alpha: 41 Feature: yr Coefficient: 1015.0602226430597
# Alpha: 41 Feature: mnth Coefficient: -100.03952614356626
# Alpha: 41 Feature: holiday Coefficient: -83.2939598752991
# Alpha: 41 Feature: weekday Coefficient: 132.50446549095798
# Alpha: 41 Feature: workingday Coefficient: 51.557085614073884
# Alpha: 41 Feature: weathersit Coefficient: -330.55985673998146
# Alpha: 41 Feature: temp Coefficient: 370.6798550300324
# Alpha: 41 Feature: atemp Coefficient: 581.3969310654994
# Alpha: 41 Feature: hum Coefficient: -140.00740550068855
# Alpha: 41 Feature: windspeed(mph) Coefficient: -191.7714084713612
# Alpha: 41 Feature: windspeed(ms) Coefficient: -2.6843848098919856e-08
# Alpha: 46 Feature: season Coefficient: 532.0189828413535
# Alpha: 46 Feature: yr Coefficient: 1015.0602226430597
# Alpha: 46 Feature: mnth Coefficient: -100.03952614356626
# Alpha: 46 Feature: holiday Coefficient: -83.2939598752991
# Alpha: 46 Feature: weekday Coefficient: 132.50446549095798
# Alpha: 46 Feature: workingday Coefficient: 51.557085614073884
# Alpha: 46 Feature: weathersit Coefficient: -330.55985673998146
# Alpha: 46 Feature: temp Coefficient: 370.6798550300324
# Alpha: 46 Feature: atemp Coefficient: 581.3969310654994
# Alpha: 46 Feature: hum Coefficient: -140.00740550068855
# Alpha: 46 Feature: windspeed(mph) Coefficient: -191.7714084713612
# Alpha: 46 Feature: windspeed(ms) Coefficient: -2.6843848098919856e-08
# Alpha: 51 Feature: season Coefficient: 532.0189828413535
# Alpha: 51 Feature: yr Coefficient: 1015.0602226430597
# Alpha: 51 Feature: mnth Coefficient: -100.03952614356626
# Alpha: 51 Feature: holiday Coefficient: -83.2939598752991
# Alpha: 51 Feature: weekday Coefficient: 132.50446549095798
# Alpha: 51 Feature: workingday Coefficient: 51.557085614073884
# Alpha: 51 Feature: weathersit Coefficient: -330.55985673998146
# Alpha: 51 Feature: temp Coefficient: 370.6798550300324
# Alpha: 51 Feature: atemp Coefficient: 581.3969310654994
# Alpha: 51 Feature: hum Coefficient: -140.00740550068855
# Alpha: 51 Feature: windspeed(mph) Coefficient: -191.7714084713612
# Alpha: 51 Feature: windspeed(ms) Coefficient: -2.6843848098919856e-08
# Alpha: 56 Feature: season Coefficient: 532.0189828413535
# Alpha: 56 Feature: yr Coefficient: 1015.0602226430597
# Alpha: 56 Feature: mnth Coefficient: -100.03952614356626
# Alpha: 56 Feature: holiday Coefficient: -83.2939598752991
# Alpha: 56 Feature: weekday Coefficient: 132.50446549095798
# Alpha: 56 Feature: workingday Coefficient: 51.557085614073884
# Alpha: 56 Feature: weathersit Coefficient: -330.55985673998146
# Alpha: 56 Feature: temp Coefficient: 370.6798550300324
# Alpha: 56 Feature: atemp Coefficient: 581.3969310654994
# Alpha: 56 Feature: hum Coefficient: -140.00740550068855
# Alpha: 56 Feature: windspeed(mph) Coefficient: -191.7714084713612
# Alpha: 56 Feature: windspeed(ms) Coefficient: -2.6843848098919856e-08
# Alpha: 61 Feature: season Coefficient: 532.0189828413535
# Alpha: 61 Feature: yr Coefficient: 1015.0602226430597
# Alpha: 61 Feature: mnth Coefficient: -100.03952614356626
# Alpha: 61 Feature: holiday Coefficient: -83.2939598752991
# Alpha: 61 Feature: weekday Coefficient: 132.50446549095798
# Alpha: 61 Feature: workingday Coefficient: 51.557085614073884
# Alpha: 61 Feature: weathersit Coefficient: -330.55985673998146
# Alpha: 61 Feature: temp Coefficient: 370.6798550300324
# Alpha: 61 Feature: atemp Coefficient: 581.3969310654994
# Alpha: 61 Feature: hum Coefficient: -140.00740550068855
# Alpha: 61 Feature: windspeed(mph) Coefficient: -191.7714084713612
# Alpha: 61 Feature: windspeed(ms) Coefficient: -2.6843848098919856e-08
# Alpha: 66 Feature: season Coefficient: 532.0189828413535
# Alpha: 66 Feature: yr Coefficient: 1015.0602226430597
# Alpha: 66 Feature: mnth Coefficient: -100.03952614356626
# Alpha: 66 Feature: holiday Coefficient: -83.2939598752991
# Alpha: 66 Feature: weekday Coefficient: 132.50446549095798
# Alpha: 66 Feature: workingday Coefficient: 51.557085614073884
# Alpha: 66 Feature: weathersit Coefficient: -330.55985673998146
# Alpha: 66 Feature: temp Coefficient: 370.6798550300324
# Alpha: 66 Feature: atemp Coefficient: 581.3969310654994
# Alpha: 66 Feature: hum Coefficient: -140.00740550068855
# Alpha: 66 Feature: windspeed(mph) Coefficient: -191.7714084713612
# Alpha: 66 Feature: windspeed(ms) Coefficient: -2.6843848098919856e-08
# Alpha: 71 Feature: season Coefficient: 532.0189828413535
# Alpha: 71 Feature: yr Coefficient: 1015.0602226430597
# Alpha: 71 Feature: mnth Coefficient: -100.03952614356626
# Alpha: 71 Feature: holiday Coefficient: -83.2939598752991
# Alpha: 71 Feature: weekday Coefficient: 132.50446549095798
# Alpha: 71 Feature: workingday Coefficient: 51.557085614073884
# Alpha: 71 Feature: weathersit Coefficient: -330.55985673998146
# Alpha: 71 Feature: temp Coefficient: 370.6798550300324
# Alpha: 71 Feature: atemp Coefficient: 581.3969310654994
# Alpha: 71 Feature: hum Coefficient: -140.00740550068855
# Alpha: 71 Feature: windspeed(mph) Coefficient: -191.7714084713612
# Alpha: 71 Feature: windspeed(ms) Coefficient: -2.6843848098919856e-08
# Alpha: 76 Feature: season Coefficient: 532.0189828413535
# Alpha: 76 Feature: yr Coefficient: 1015.0602226430597
# Alpha: 76 Feature: mnth Coefficient: -100.03952614356626
# Alpha: 76 Feature: holiday Coefficient: -83.2939598752991
# Alpha: 76 Feature: weekday Coefficient: 132.50446549095798
# Alpha: 76 Feature: workingday Coefficient: 51.557085614073884
# Alpha: 76 Feature: weathersit Coefficient: -330.55985673998146
# Alpha: 76 Feature: temp Coefficient: 370.6798550300324
# Alpha: 76 Feature: atemp Coefficient: 581.3969310654994
# Alpha: 76 Feature: hum Coefficient: -140.00740550068855
# Alpha: 76 Feature: windspeed(mph) Coefficient: -191.7714084713612
# Alpha: 76 Feature: windspeed(ms) Coefficient: -2.6843848098919856e-08
# Alpha: 81 Feature: season Coefficient: 532.0189828413535
# Alpha: 81 Feature: yr Coefficient: 1015.0602226430597
# Alpha: 81 Feature: mnth Coefficient: -100.03952614356626
# Alpha: 81 Feature: holiday Coefficient: -83.2939598752991
# Alpha: 81 Feature: weekday Coefficient: 132.50446549095798
# Alpha: 81 Feature: workingday Coefficient: 51.557085614073884
# Alpha: 81 Feature: weathersit Coefficient: -330.55985673998146
# Alpha: 81 Feature: temp Coefficient: 370.6798550300324
# Alpha: 81 Feature: atemp Coefficient: 581.3969310654994
# Alpha: 81 Feature: hum Coefficient: -140.00740550068855
# Alpha: 81 Feature: windspeed(mph) Coefficient: -191.7714084713612
# Alpha: 81 Feature: windspeed(ms) Coefficient: -2.6843848098919856e-08
# Alpha: 86 Feature: season Coefficient: 532.0189828413535
# Alpha: 86 Feature: yr Coefficient: 1015.0602226430597
# Alpha: 86 Feature: mnth Coefficient: -100.03952614356626
# Alpha: 86 Feature: holiday Coefficient: -83.2939598752991
# Alpha: 86 Feature: weekday Coefficient: 132.50446549095798
# Alpha: 86 Feature: workingday Coefficient: 51.557085614073884
# Alpha: 86 Feature: weathersit Coefficient: -330.55985673998146
# Alpha: 86 Feature: temp Coefficient: 370.6798550300324
# Alpha: 86 Feature: atemp Coefficient: 581.3969310654994
# Alpha: 86 Feature: hum Coefficient: -140.00740550068855
# Alpha: 86 Feature: windspeed(mph) Coefficient: -191.7714084713612
# Alpha: 86 Feature: windspeed(ms) Coefficient: -2.6843848098919856e-08
# Alpha: 91 Feature: season Coefficient: 532.0189828413535
# Alpha: 91 Feature: yr Coefficient: 1015.0602226430597
# Alpha: 91 Feature: mnth Coefficient: -100.03952614356626
# Alpha: 91 Feature: holiday Coefficient: -83.2939598752991
# Alpha: 91 Feature: weekday Coefficient: 132.50446549095798
# Alpha: 91 Feature: workingday Coefficient: 51.557085614073884
# Alpha: 91 Feature: weathersit Coefficient: -330.55985673998146
# Alpha: 91 Feature: temp Coefficient: 370.6798550300324
# Alpha: 91 Feature: atemp Coefficient: 581.3969310654994
# Alpha: 91 Feature: hum Coefficient: -140.00740550068855
# Alpha: 91 Feature: windspeed(mph) Coefficient: -191.7714084713612
# Alpha: 91 Feature: windspeed(ms) Coefficient: -2.6843848098919856e-08
# Alpha: 96 Feature: season Coefficient: 532.0189828413535
# Alpha: 96 Feature: yr Coefficient: 1015.0602226430597
# Alpha: 96 Feature: mnth Coefficient: -100.03952614356626
# Alpha: 96 Feature: holiday Coefficient: -83.2939598752991
# Alpha: 96 Feature: weekday Coefficient: 132.50446549095798
# Alpha: 96 Feature: workingday Coefficient: 51.557085614073884
# Alpha: 96 Feature: weathersit Coefficient: -330.55985673998146
# Alpha: 96 Feature: temp Coefficient: 370.6798550300324
# Alpha: 96 Feature: atemp Coefficient: 581.3969310654994
# Alpha: 96 Feature: hum Coefficient: -140.00740550068855
# Alpha: 96 Feature: windspeed(mph) Coefficient: -191.7714084713612
# Alpha: 96 Feature: windspeed(ms) Coefficient: -2.6843848098919856e-08

# %% [markdown]
# Итак, мы выбрали некоторый параметр регуляризации. Давайте посмотрим, какие бы мы выбирали alpha, если бы делили выборку только один раз на обучающую и тестовую, то есть рассмотрим траектории MSE, соответствующие отдельным блокам выборки.

# %%
# Код 3.3 (1 балл)
# Выведите значения alpha, соответствующие минимумам MSE на каждом разбиении (то есть по столбцам).
# На трех отдельных графиках визуализируйте столбцы .mse_path_
argmin_mse = np.zeros(lasso_cv.mse_path_.shape[1])
for i in range(lasso_cv.mse_path_.shape[1]):
    argmin_mse = int(np.argmin(lasso_cv.mse_path_[:, i], axis=0))
    print(alphas[argmin_mse], lasso_cv.mse_path_[argmin_mse][i])
    plt.plot(alphas, lasso_cv.mse_path_[:, i])
plt.xlabel('Alphas')
plt.ylabel('MSE')
# Out:
# 56 843336.1814988198
# 91 772598.4956277697
# 96 745668.6059608029
# Text(0, 0.5, 'MSE')

# %% [markdown]
# На каждом разбиении оптимальное значение alpha свое, и ему соответствует большое MSE на других разбиениях. Получается, что мы настраиваемся на конкретные обучающие и контрольные выборки. При выборе alpha на кросс-валидации мы выбираем нечто "среднее", что будет давать приемлемое значение метрики на разных разбиениях выборки.

# %% [markdown]
# Наконец, как принято в анализе данных, давайте проинтерпретируем результат.

# %% [markdown]
# __Блок 3. Ответьте на вопросы (каждый 0.5 балла):__
# 1. В последней обученной модели выберите 4 признака с наибольшими (положительными) коэфициентами (и выпишите их), посмотрите на визуализации зависимостей cnt от этих признаков, которые мы рисовали в блоке "Знакомство с данными". Видна ли возрастающая линейная зависимость cnt от этих признаков по графикам? Логично ли утверждать (из здравого смысла), что чем больше значение этих признаков, тем больше людей захотят взять велосипеды?
#     * Ответ: yr, season, temp, atemp. У данных признаков наблюдается возрастающая линейная зависимость. Можно предположить, что чем больше значение данных признаков, тем больше захотят арендовать велосипедов.
# 1. Выберите 3 признака с наибольшими по модулю отрицательными коэффициентами (и выпишите их), посмотрите на соответствующие визуализации. Видна ли убывающая линейная зависимость? Логично ли утверждать, что чем больше величина этих признаков, тем меньше людей захотят взять велосипеды?
#     * Ответ: mnth, wherthesit, windspeed(mph). Точно такое рассуждение с отрицательными признаками.
# 1. Выпишите признаки с коэффициентами, близкими к нулю (< 1e-3). Как вы думаете, почему модель исключила их из модели (вновь посмотрите на графики)? Верно ли, что они никак не влияют на спрос на велосипеды?
#     * Ответ: windspeed(ms). Т.к. два признака линейно выражаются друг из друга, один из них можно занулить и этот признак не будет влиять на спрос велосипедов.

# %% [markdown]
# ### Заключение
# Итак, мы посмотрели, как можно следить за адекватностью линейной модели, как отбирать признаки и как грамотно, по возможности не настраиваясь на какую-то конкретную порцию данных, подбирать коэффициент регуляризации.
#
# Стоит отметить, что с помощью кросс-валидации удобно подбирать лишь небольшое число параметров (1, 2, максимум 3), потому что для каждой допустимой их комбинации нам приходится несколько раз обучать модель, а это времязатратный процесс, особенно если нужно обучаться на больших объемах данных.
